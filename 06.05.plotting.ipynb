# %% [markdown]
# # Plotting Basics

# %% [markdown]
# The most common data structures that you will be plotting will be either single `pandas` `Series` or `pandas` `dataframes`, **see:** [heatmaps](https://seaborn.pydata.org/generated/seaborn.heatmap.html).
#
# You will also find yourself plotting `numpy` arrays on occasion, and luckily, the format will remain the same! We just pass in the required amount of data for the plot in question.

# %% [markdown]
# ### Import `pandas`
# We use the `as` keyword to give the `pandas` package the customary `pd` alias. This allows us to reference the `pandas` library with that `alias`

# %% [markdown]
# ```python
# import pandas as pd
# ```

# %%
import pandas as pd

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# <hr>
#
# ##### Mount Drive - **Google Colab Only Step**
#
# When using google colab in order to access files on our google drive we need to mount the drive by running the below python cell, then clicking the link it generates and pasting the code in the cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change Directory To Access The Dependent Files - **Google Colab Only Step**

# %%
directory = "teacher"
if (directory == "student"):
  # %cd drive/Colab\ Notebooks/intro-to-python/
else:
  # %cd drive/Shared\ drives/Rubrik/Data\ Science\ Track/intro-to-python
# Out:
# [Errno 2] No such file or directory: 'drive/Shared drives/Rubrik/Data Science Track/intro-to-python'
# /content/drive/Shared drives/Rubrik/Data Science Track/intro-to-python

# %% [markdown]
# #### Load Titanic data into a variable called `df`

# %% [markdown]
# ```python
# df = pd.read_csv("./data/titanic-survival.csv")
# ```

# %%
df = pd.read_csv("./data/titanic-survival.csv")

# %% [markdown]
# ### **Look at the `head` of `df`**

# %% [markdown]
# ```python
# df.head()
# ```

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Look at `Age` column
#
# We will be looking at the `Age` column today since our first plot will be a `histogram`, which attempts to describe the `distribution` of the underlying data in question.

# %% [markdown]
# Here we look at the first 20 values in the `Age` column.
# ```python
# df['Age'].head(20)
# ```

# %%
df['Age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %% [markdown]
# <hr>
# <br>
# <br>
# <br>

# %% [markdown]
# ## 2. Plot Data
# <hr>

# %% [markdown]
# ## Matplotlib
#
# The first library we will be looking at is called `matplotlib`, we will be making plots thorugh its `pyplot` sub-module.
#
# We can access `pyplot` by using the `.` operator on the `matplotlib` `import` statement. This gives us:
# > `import` `matplotlib.pyplot`.
#
# We should add the familiar `as` parameter to alias that entire library import down to just `plt`.
# > `import` `matplotlib.pyplot` `as` `plt`
#
# This simplifies invoking a `histogram` considerably, we go from typing out `matplotlib.pyplot.hist()` *every single time.* to just `plt.hist()`, much better.

# %% [markdown]
# ### 1. Import `matplotlib.pyplot` package

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# <br>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Basic Matplotlib Commands
#
# We can create a very simple `Histogram` plot using the `Age` feature of the Titanic Dataset above, stored in `df`.
#
# [Matplotlib Hist documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html)

# %% [markdown]
# #### Single plot on `figure` and `axis` objects.

# %% [markdown]
# There is a very simple analogy to remember the lines of code that you have to write to create and view a matplotlib plot in jupyter notebook. Think of making and displaying a plot, the way an artist completes a painting.
#
# 1. Stand up the Easel
# 2. Place Blank Canvas on the easel
# 3. "Draw" whatever plot on Canvas
# 4. "Hang" Canvas on Wall

# %% [markdown]
# <br>

# %% [markdown]
# ### 3. Simple Plot of the `Age` Feature
#
# ```python
# # Stand up the Easel
# fig = plt.figure()
#
# # Place Blank Canvas on the easel
# ax = fig.gca()
#
# # "Draw" a histogram onto the Canvas
# ax.hist(df['Age'])
#
# # Hang Canvas on Wall
# plt.show()
# ```

# %%
# Stand up the Easel
fig = plt.figure()
 
# Place Blank Canvas on the easel
ax = fig.gca()
 
# "Draw" a histogram onto the Canvas
ax.hist(df['Age'])
 
# Hang Canvas on Wall
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# <br>

# %% [markdown]
# ### 4. With Labels and Titles
#
# Things get a whole lot more complex looking, but just because the ode below `looks` harder, doesn't make it so. I would not recommend remembering the specific commands to create labels and add titles, especially with the `seaborn` library that we will see in month 2.
#
# ```python
# # Set a figure
# fig = plt.figure()
#
# # Grab `ax` object
# ax = fig.gca()
#
# # Fig Title
# fig.suptitle("Histogram of Ages")
#
# # Ax Title
# ax.set_title("For all Passengers Aboard RMS Titanic")
#
# # Plot data
# ax.hist(df['Age'])
#
# # Labels
# ax.set_xlabel("Passenger Age")
# ax.set_ylabel("Frequency")
#
#
# # Clean up output
# plt.show()
# ```

# %%
# Set a figure
fig = plt.figure()
 
# Grab `ax` object
ax = fig.gca()
 
# Fig Title
fig.suptitle("Histogram of Ages")
 
# Ax Title
ax.set_title("For all Passengers Aboard RMS Titanic")
 
# Plot data
ax.hist(df['Age'])
 
# Labels
ax.set_xlabel("Passenger Age")
ax.set_ylabel("Frequency")
 
 
# Clean up output
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ### 5. Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %% [markdown]
# #### To save a figure to a file we can use the `savefig` method on the `fig` object we created above:

# %% [markdown]
# ```python
# filePath = "./data/age-histogram.png"
# fig.savefig(filePath)
# ```

# %%
filePath = "./data/age-histogram.png"
fig.savefig(filePath)

# %% [markdown]
# #### Here we can also optionally specify the DPI and choose between different output formats:

# %% [markdown]
# ```python
# filePath = "./data/age-histogram-200-dpi.png"
# fig.savefig(filePath, dpi=200)
# ```

# %%
filePath = "./data/age-histogram-200-dpi.png"
fig.savefig(filePath, dpi=200)

# %% [markdown]
# <hr>
# <br>
# <center><h1 style = 'color:red'>-----------Plotting Exercise (1)-------------</h1></center>
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Seaborn
#
# The second library we will be looking at is called `seaborn`.
#
# We should add the familiar `as` parameter to alias that entire library down to just `sns`.
# > `import` `seaborn` `as` `sns`

# %%
import seaborn as sns

# %% [markdown]
# ### 1. Simpler Plot of the `Age` Feature Using Seaborn
#
# Seaborn's histogram plot function is called `distplot`.
#
# [Seaborn distplot documentation](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# We have to chain .dropna() so seaborn doesn't try to plot Nan values — other wise the plot will break.
#
# ```python
# # "Draw" a histogram, seaborn handles ax and fig
# sns.distplot(df['Age'].dropna())
#
# # Remove unwanted output
# plt.show()
# ```

# %%
# "Draw" a histogram, seaborn handles ax and fig
sns.distplot(df['Age'].dropna())
 
# Remove unwanted output
plt.show()

# %% [markdown]
# ### 2. Combine approaches for added control.
#
# ```python
# # Stand up the Easel
# fig = plt.figure()
#
# # Place Blank Canvas on the easel
# ax = fig.gca()
#
# # Add labels and title
# ax.set_title('A Distribution Plot for the Age Variable')
# ax.set_ylabel('Frequency')
#
# # "Draw" a histogram onto the Canvas, pass in ax to ax seaborn parameter
# sns.distplot(df['Age'].dropna(), ax=ax) # don't forget to drop NAN values
#
# # Hang Canvas on Wall
# plt.show()
# ```

# %%
# Stand up the Easel
fig = plt.figure()
 
# Place Blank Canvas on the easel
ax = fig.gca()
 
# Add labels and title
ax.set_title('A Distribution Plot for the Age Variable')
ax.set_ylabel('Frequency')
 
# "Draw" a histogram onto the Canvas, pass in ax to ax seaborn parameter
sns.distplot(df['Age'].dropna(), ax=ax) # don't forget to drop NAN values
 
# Hang Canvas on Wall
plt.show()

# %% [markdown]
# <a id='seaborn'></a>

# %% [markdown]
# ### 3. Save `fig` object to save entire image.
#
# [Same as before](#savefig)

# %%
filePath = "./data/seaborn-age-histogram-200-dpi.png"
fig.savefig(filePath, dpi=200)

# %% [markdown]
# <hr>
# <br>
# <center><h1 style = 'color:red'>-----------Plotting Exercise (2)-------------</h1></center>
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Pandas Built-in
#
# The third library we will be looking at you're already familiar with, but its more versatile than you previously thought!

# %% [markdown]
# ### 1. Even Simpler Plot of the `Age` Feature
#
# We have to chain `.plot.hist()` on whatever column we are interested in viewing a `histogram` for.
#
# ```python
# # "Draw" a histogram, seaborn handles ax and fig
# df['Age'].plot.hist()
#
# # Remove unwanted output
# plt.show()
# ```

# %%
# "Draw" a histogram, seaborn handles ax and fig
df['Age'].plot.hist()
 
# Remove unwanted output
plt.show()

# %% [markdown]
# ### 2. Combine approaches for added control.
#
# ```python
# # Stand up the Easel
# fig = plt.figure()
#
# # Place Blank Canvas on the easel
# ax = fig.gca()
#
# # Add labels and title
# ax.set_title('A Distribution Plot for the Age Variable')
# ax.set_ylabel('Frequency')
#
# # "Draw" a histogram onto the Canvas, pass in ax to pandas ax parameter
# df['Age'].plot.hist(ax=ax)
#
# # Hang Canvas on Wall
# plt.show()
# ```

# %%
# Stand up the Easel
fig = plt.figure()
 
# Place Blank Canvas on the easel
ax = fig.gca()
 
# Add labels and title
ax.set_title('A Distribution Plot for the Age Variable')
ax.set_ylabel('Frequency')
 
# "Draw" a histogram onto the Canvas, pass in ax to pandas ax parameter
df['Age'].plot.hist(ax=ax)
 
# Hang Canvas on Wall
plt.show()

# %% [markdown]
# <a id='pandas'></a>

# %% [markdown]
# ### 3. Save `fig` object to save entire image.
#
# [Same as before](#savefig)

# %%
filePath = "./data/pandas-age-histogram-200-dpi.png"
fig.savefig(filePath, dpi=200)

# %% [markdown]
# <hr>
# <br>
# <center><h1 style = 'color:red'>-----------Plotting Exercise (3)-------------</h1></center>
# <br>
# <hr>
# <br>
