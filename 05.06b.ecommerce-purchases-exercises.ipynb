# %% [markdown]
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions but it's recommended trying to answer for at least 5 minutes and then asking educated questions with classmates and the instructor before looking. Most of the tasks can be solved in different ways.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.

# %% [markdown]
# **Hint:**
# This may come in handy!
# [`value_counts()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html)

# %% [markdown]
# <hr>
# <br>
# <br>

# %% [markdown]
# **1. Import numpy and pandas**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **2. Load Data**

# %% [markdown]
# <hr>
#
# ##### Mount Drive - **Google Colab Only Step**
#
# When using google colab in order to access files on our google drive we need to mount the drive by running the below python cell, then clicking the link it generates and pasting the code in the cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change Directory To Access The Dependent Files - **Google Colab Only Step**

# %%
directory = "teacher"
if (directory == "student"):
  # %cd drive/Colab\ Notebooks/intro-to-python/
else:
  # %cd drive/Shared\ drives/Rubrik/Data\ Science\ Track/intro-to-python
# Out:
# /content/drive/Shared drives/Rubrik/Data Science Track/intro-to-python

# %% [markdown]
# **Read in the E-commerce Purchases csv file and set it to a DataFrame called `ecom`.**
#
# The file name is `e-commerce-purchases.csv` which is located in the `data` directory which lives inside the current directory.

# %%
ecom = pd.read_csv('./data/e-commerce-purchases.csv')

# %% [markdown]
# <br>

# %% [markdown]
# **3. Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#                                              Address  ... Purchase Price
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  ...          98.14
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  ...          70.73
# 2                   Unit 0065 Box 5052\nDPO AP 27450  ...           0.95
# 3              7780 Julia Fords\nNew Stacy, WA 45798  ...          78.04
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  ...          77.82
#
# [5 rows x 14 columns]

# %% [markdown]
# <br>

# %% [markdown]
# **4. How many `rows` and `columns` are there?**

# %%
ecom.shape
# Out:
# (10000, 14)

# %% [markdown]
# <br>

# %% [markdown]
# #### 5. What does each `row` represent? A person, A company, ...??

# %% [markdown]
# An individual's Transaction

# %% [markdown]
# <br>

# %% [markdown]
# **6. What is the `dtype` of the `Company` column?**

# %%
ecom['Company'].dtype
# Out:
# dtype('O')

# %% [markdown]
# An Object or string

# %% [markdown]
# <br>

# %% [markdown]
# **7. How many `unique` `companies` in `Company` column?**

# %%
ecom['Company'].nunique()
# Out:
# 8653

# %% [markdown]
# <br>

# %% [markdown]
# **8. What is the average `Purchase Price`?**

# %%
def mode(series):
  return series.value_counts().index[0]

# %%
df['Purchase Price'].agg([np.mean, np.median, mode])
# Out:
# mean      50.347302
# median    50.505000
# mode      49.730000
# Name: Purchase Price, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# **9. What were the highest and lowest purchase prices?**

# %%
df['Purchase Price'].agg([np.min, np.max])
# Out:
# amin     0.00
# amax    99.99
# Name: Purchase Price, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# **10. How many people have English 'en' as their Language of choice on the website?**
# <br>
# How do we `count` how many rows belong to a certain unique `value` of a column...?

# %%
# is_en = ecom['Language'] == 'en'
# ecom[is_en]['Language'].value_counts()

# even better
ecom["Language"].value_counts()['en']
# Out:
# en    1098
# Name: Language, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# **11. How many people have the job title of `Lawyer`?**

# %%
ecom['Job'].value_counts()["Lawyer"]
# Out:
# 30

# %% [markdown]
# <br>

# %% [markdown]
# **12. How many people made the purchase during the AM and how many people made the purchase during PM?**

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# **13. What are the 5 most common Job Titles?**

# %%
ecom['Job'].value_counts().head()
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
# Name: Job, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# **14. Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?**

# %%
ecom[ecom['Lot'] == "90 WT"]['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# **15. What is the email of the person with the following Credit Card Number: `4926535242672853`**

# %%
ecom[ecom['Credit Card'] == 4926535242672853]["Email"]
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# **16. How many people have American Express as their Credit Card Provider AND made a purchase above $95?**

# %%
is_american_express = ecom['CC Provider'] == 'American Express'
is_purchase_price_gt_95 = ecom['Purchase Price'] > 95
len(ecom[( (is_american_express) & (is_purchase_price_gt_95) )])
# Out:
# 39

# %% [markdown]
# <br>

# %% [markdown]
# ## Bonus Questions!
#
# Ask Questions with peers and facilitator!

# %% [markdown]
# **<span style="color:red">Hard:</span> How many people have a credit card that expires in 2025?**
# <br>
# I don't expect you to be able to do this yet.

# %%
( ecom["CC Exp Date"].str.split('/', expand=True).astype(int) == 25 )[1].sum()
# Out:
# 1033

# %% [markdown]
# <br>

# %% [markdown]
# **<span style="color:red">More Challenging:</span> What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)**

# %%
ecom['Email'].str.split('@', expand=True)[1].value_counts()[:5]
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: 1, dtype: int64
