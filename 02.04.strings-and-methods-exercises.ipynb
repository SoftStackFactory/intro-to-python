# %% [markdown]
# # 1. Create Sentences out of Strings
# <hr>
#
# Create the following sentence: `Learning Python is fun!`, as depicted in the `assert` cell below.
#
# Use the variables `verb`, `language`, and `punctuation` as well as any other strings you may need!
#
# <hr>

# %%
verb = 'Learning'
lang = ' Python'
punctuation = '!'

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Your Answer:

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Test Your answer!

# %%
print('sentence:', sentence)
# Out:
# sentence: Learning Python is fun!

# %% [markdown]
# <br>

# %% [markdown]
# #### Let's make sure that your solution is sound. `assert` raises [`AssertionError`](https://docs.python.org/3/library/exceptions.html#AssertionError) if the statement is not `True`.
# `==` is asking `are these equal`

# %%
# Your sentence should look like:
assert sentence == 'Learning Python is fun!'

# %% [markdown]
# <hr>
# <br>
# <br>

# %% [markdown]
# # 2. Mutate strings
# <hr>
#
# Call the appropriate string methods on `original` to match the variables depicted in the `assert` cells below.
# Remember that string methods do not automatically mutate the original, so you have to save changes to a new variable, or overwrite the old one.
# <br>
# In these exercises we are creating new variables out of the mutations on `original`
# <hr>

# %%
original = '     Python strings are COOL! '

# %% [markdown]
# <br>

# %% [markdown]
# ### Force all chars in `original` to lower case.

# %% [markdown]
# <br>

# %%
assert lower_cased == '     python strings are cool! '

# %% [markdown]
# <br>

# %% [markdown]
# ### Remove the trailing and leading white space on `original`

# %% [markdown]
# <br>

# %%
assert white_space_stripped == 'Python strings are COOL!'

# %% [markdown]
# <br>

# %% [markdown]
# ### Force all chars to lower case `AND` remove trailing and leading whitespace on `original`

# %% [markdown]
# <br>

# %%
assert stripped_and_lower_cased == 'python strings are cool!'

# %% [markdown]
# <br>

# %% [markdown]
# <hr>
# <br>
# <br>

# %% [markdown]
# # 3. "Prettify" an ugly string
# <hr>
#
# Use `str` methods to convert `ugly` to `pretty`.
# <br>
# Some chaining will be invovled to fix the string,
# <br>
# It has to look like the title of a book!
#
# Pretty should have the following value: `'Title Of My New Book'`
#
# <hr>

# %%
ugly = ' tiTle of MY new Book       '

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Your Answer:

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Test Your Answer

# %%
print('pretty:', pretty)
# Out:
# pretty: Title Of My New Book

# %% [markdown]
# <br>

# %% [markdown]
# #### Let's make sure that your solution is sound. `assert` raises [`AssertionError`](https://docs.python.org/3/library/exceptions.html#AssertionError) if the statement is not `True`.
# `==` is asking `are these equal`

# %%
assert pretty == 'Title Of My New Book'
